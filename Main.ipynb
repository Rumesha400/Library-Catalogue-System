# %%
import Function as f
print("Menu:\n1. Login\n2. Exit")
choice = int(input("Enter the number from the menu that you want to do: "))
print("-----------------------------------------------------------------------")
if choice == 1:
    if f.Login():
        f.Menue()
elif choice == 2:
    pass
# Out:
# Menu:
# 1. Login
# 2. Exit
# Enter the number from the menu that you want to do: 1
# -----------------------------------------------------------------------
# Enter the Password: Ad123@mi
# -----------------------------------------------------------------------
# -------------------------- Successful Login --------------------------
# Menue:
# 1.Add Section
# 2.Seeing and updating The inventory
# 3.Seeing Plots
# 4.Exit
# Enter the number from the menue that you want to do: 3
# -----------------------------------------------------------------------
# Menue:
# 1.Title VS Genre
# 2.Title VS Author
# 3.Exit
# Enter the number from the menue that you want to do: 2
# -----------------------------------------------------------------------
# Menue:
# 1.Title VS Genre
# 2.Title VS Author
# 3.Exit
# Enter the number from the menue that you want to do: 3
# -----------------------------------------------------------------------
# Menue:
# 1.Add Section
# 2.Seeing and updating The inventory
# ...
